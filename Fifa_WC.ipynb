# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa_data = pd.read_csv("players_22.csv", low_memory=False)

# %%
fifa_data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
del fifa_data["sofifa_id"]
del fifa_data["player_url"]

# %%
fifa_data.head()
# Out:
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age         dob  height_cm  ...  \
# 0       93         93   78000000.0  320000.0   34  1987-06-24        170  ...
# 1       92         92  119500000.0  270000.0   32  1988-08-21        185  ...
# 2       91         91   45000000.0  270000.0   36  1985-02-05        187  ...
# 3       91         91  129000000.0  270000.0   29  1992-02-05        175  ...
# 4       91         91  125500000.0  350000.0   30  1991-06-28        181  ...
#
#     lcb    cb   rcb    rb    gk  \
# ...

# %%
#1) Goalkeeper:
# weights:
a=0.5
b=1
c=2
d=3

# %%
fifa_data["GK"]= (b*fifa_data.movement_reactions+a*fifa_data.goalkeeping_speed+a*fifa_data.power_strength+
                  c*fifa_data.power_jumping+b*fifa_data.goalkeeping_positioning+c*fifa_data.goalkeeping_diving+
                  d*fifa_data.goalkeeping_reflexes+ b*fifa_data.goalkeeping_handling+ c*fifa_data.goalkeeping_kicking)/(2*a+3*b+3*c+d)

# %%
plt.figure(figsize=(15,6))
gk1= fifa_data.sort_values("GK",ascending= False)[:10]
x1= np.array(list(gk1["short_name"]))
y1= np.array(list(gk1["GK"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
#2) Defense:
#club_position,nation_position,preferred_foot,weak_foot,skill_moves,work_rate,body_type,real_face,release_clause_eur,player_tags,
#player_traits,pace,shooting,passing,dribbling,defending,physic,attacking_crossing,attacking_finishing,attacking_heading_accuracy,
#attacking_short_passing,attacking_volleys,skill_dribbling,skill_curve,skill_fk_accuracy,skill_long_passing,skill_ball_control,
#movement_acceleration,movement_sprint_speed,movement_agility,movement_reactions,movement_balance,power_shot_power,power_jumping,
#power_stamina,power_strength,power_long_shots,
#mentality_aggression,mentality_interceptions,mentality_positioning,mentality_vision,mentality_penalties,mentality_composure,
#defending_marking_awareness,defending_standing_tackle,defending_sliding_tackle
#position: ls,st,rs,lw,lf,cf,rf,rw,lam,cam,ram,lm,lcm,cm,rcm,rm,lwb,ldm,cdm,rdm,rwb,lb,lcb,cb,rcb,rb,gk

# %%
fifa_data.club_position.unique()
# Out:
# array(['RW', 'ST', 'LW', 'RCM', 'GK', 'CF', 'CDM', 'LCB', 'RDM', 'RS',
#        'LCM', 'SUB', 'CAM', 'RCB', 'LDM', 'LB', 'RB', 'LM', 'RM', 'LS',
#        'CB', 'RES', nan, 'RWB', 'RF', 'CM', 'LWB', 'LAM', 'LF', 'RAM'],
#       dtype=object)

# %%
# see website, rechter Verteidiger: RH, RB, RWB, WB

# %%
# %pylab inline
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg. imread('positions.png')
imgplot = plt. imshow(img)
plt. show()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
fifa_data.loc[(fifa_data.club_position == ("RB"))]
# Out:
#                 short_name               long_name player_positions  overall  \
# 44     T. Alexander-Arnold  Trent Alexander-Arnold               RB       87
# 80               K. Walker             Kyle Walker               RB       85
# 87                Carvajal   Daniel Carvajal Ramos               RB       85
# 95               A. Hakimi      Achraf Hakimi Mouh          RB, RWB       85
# 98             Jesús Navas    Jesús Navas González           RB, RM       84
# ...                    ...                     ...              ...      ...
# 17869             P. Lakra            Provat Lakra           LB, RB       55
# 18070           A. Hawsawi        Abdullah Hawsawi               RB       55
# 18189           S. Sarangi         Shubham Sarangi           RB, RM       54
# 18694        Yeljan Shinar                 叶利江·什那尔               RB       52
# 19003          K. Chambers           Karl Chambers               RB       50
#
# ...

# %%
# so only RB and RWB

# %%
fifa_data.player_positions.str.split(",",expand=True)
# Out:
#          0     1     2
# 0       RW    ST    CF
# 1       ST  None  None
# 2       ST    LW  None
# 3       LW   CAM  None
# 4       CM   CAM  None
# ...    ...   ...   ...
# 19234  CDM  None  None
# 19235   CM  None  None
# 19236   CM  None  None
# 19237   ST  None  None
# 19238  CAM  None  None
#
# [19239 rows x 3 columns]

# %%
fifa_data["P0"]= fifa_data.player_positions.str.split(",",expand=True)[0]
fifa_data["P1"]= fifa_data.player_positions.str.split(",",expand=True)[1]
fifa_data["P2"]= fifa_data.player_positions.str.split(",",expand=True)[2]

# %%
fifa_data_potRB=fifa_data[fifa_data.P0.isin(["RB", "RWB"])]

# %%
fifa_data_potRB
# Out:
#                 short_name                  long_name player_positions  \
# 44     T. Alexander-Arnold     Trent Alexander-Arnold               RB
# 62            João Cancelo  João Pedro Cavaco Cancelo           RB, LB
# 80               K. Walker                Kyle Walker               RB
# 87                Carvajal      Daniel Carvajal Ramos               RB
# 95               A. Hakimi         Achraf Hakimi Mouh          RB, RWB
# ...                    ...                        ...              ...
# 19113             R. Aimol          Reamsochung Aimol           RB, RM
# 19127        J. Zoherliana             Joe Zoherliana           RB, LB
# 19142            C. Talbot              Callum Talbot               RB
# 19199             A. Nawab                 Aqib Nawab               RB
# 19200           B. Ganesan             Balaji Ganesan               RB
#
#        overall  potential    value_eur  wage_eur  age         dob  height_cm  \
# ...

# %%
# parameters:
#weak_foot,skill_moves,work_rate,body_type,real_face,release_clause_eur,player_tags,
#player_traits,pace,shooting,passing,dribbling,defending,physic,attacking_crossing,attacking_finishing,attacking_heading_accuracy,
#attacking_short_passing,attacking_volleys,skill_dribbling,skill_curve,skill_fk_accuracy,skill_long_passing,skill_ball_control,
#movement_acceleration,movement_sprint_speed,movement_agility,movement_reactions,movement_balance,power_shot_power,power_jumping,
#power_stamina,power_strength,power_long_shots,
#mentality_aggression,mentality_interceptions,mentality_positioning,mentality_vision,mentality_penalties,mentality_composure,
#defending_marking_awareness,defending_standing_tackle,defending_sliding_tackle

# %%
fifa_data.passing.unique()
# Out:
# array([91., 79., 80., 86., 93., nan, 83., 75., 81., 82., 76., 71., 74.,
#        89., 65., 67., 87., 85., 88., 60., 77., 90., 51., 64., 70., 78.,
#        72., 53., 84., 69., 57., 58., 73., 44., 68., 55., 62., 61., 59.,
#        56., 63., 66., 52., 50., 49., 48., 54., 47., 45., 46., 38., 40.,
#        43., 39., 41., 35., 42., 36., 37., 34., 33., 31., 32., 29., 28.,
#        25., 30., 27.])

# %%
# chosen parameters:
# weak_foot,pace,shooting,passing,dribbling,defending,attacking_crossing
#movement_acceleration,movement_sprint_speed,movement_agility,movement_reactions,movement_balance
#power_stamina #mentality_aggression,mentality_interceptions,mentality_positioning,mentality_vision
#defending_marking_awareness,defending_standing_tackle,defending_sliding_tackle

# %%
#a weak_foot, shooting
#b dribbling,attacking_crossing, movement_acceleration, movement_sprint_speed, movement_agility, movement_reactions
# movement_balance, mentality_aggression, mentality_vision
#c pace, passing, power_stamina, mentality_interceptions
#d defending, mentality_positioning, defending_marking_awareness, defending_standing_tackle, defending_sliding_tackle

# %%
fifa_data["RB"]= (a*fifa_data.weak_foot*20+a*fifa_data.shooting+
                  b*fifa_data.dribbling+b*fifa_data.attacking_crossing+b*fifa_data.movement_acceleration+
                  b*fifa_data.movement_sprint_speed+b*fifa_data.movement_agility+b*fifa_data.movement_reactions+
                  b*fifa_data.movement_balance+b*fifa_data.mentality_aggression+b*fifa_data.mentality_vision+
                  c*fifa_data.pace+c*fifa_data.passing+c*fifa_data.power_stamina+c*fifa_data.mentality_interceptions+
                  d*fifa_data.defending+d*fifa_data.mentality_positioning+d*fifa_data.defending_marking_awareness+
                  d*fifa_data.defending_standing_tackle+d*fifa_data.defending_sliding_tackle)/(2*a+9*b+4*c+5*d)

# %%
fifa_data_potRB=fifa_data[fifa_data.P0.isin(["RB", "RWB"])]

plt.figure(figsize=(15,6))
potRB= fifa_data_potRB.sort_values("RB",ascending= False)[:10]
x1= np.array(list(potRB["short_name"]))
y1= np.array(list(potRB["RB"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
# try again with more focus on defending:
a=0.5
b=1
c=5
d=10

fifa_data["RB2"]= (a*fifa_data.weak_foot*20+a*fifa_data.shooting+
                  b*fifa_data.dribbling+b*fifa_data.attacking_crossing+b*fifa_data.movement_acceleration+
                  b*fifa_data.movement_sprint_speed+b*fifa_data.movement_agility+b*fifa_data.movement_reactions+
                  b*fifa_data.movement_balance+b*fifa_data.mentality_aggression+b*fifa_data.mentality_vision+
                  c*fifa_data.pace+c*fifa_data.passing+c*fifa_data.power_stamina+c*fifa_data.mentality_interceptions+
                  d*fifa_data.defending+d*fifa_data.mentality_positioning+d*fifa_data.defending_marking_awareness+
                  d*fifa_data.defending_standing_tackle+d*fifa_data.defending_sliding_tackle)/(2*a+9*b+4*c+5*d)

# %%
fifa_data_potRB=fifa_data[fifa_data.P0.isin(["RB", "RWB"])]

plt.figure(figsize=(15,6))
potRB= fifa_data_potRB.sort_values("RB2",ascending= False)[:10]
x1= np.array(list(potRB["short_name"]))
y1= np.array(list(potRB["RB2"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
# same for left side:
a=0.5
b=1
c=5
d=10

fifa_data["LB"]= (a*fifa_data.weak_foot*20+a*fifa_data.shooting+
                  b*fifa_data.dribbling+b*fifa_data.attacking_crossing+b*fifa_data.movement_acceleration+
                  b*fifa_data.movement_sprint_speed+b*fifa_data.movement_agility+b*fifa_data.movement_reactions+
                  b*fifa_data.movement_balance+b*fifa_data.mentality_aggression+b*fifa_data.mentality_vision+
                  c*fifa_data.pace+c*fifa_data.passing+c*fifa_data.power_stamina+c*fifa_data.mentality_interceptions+
                  d*fifa_data.defending+d*fifa_data.mentality_positioning+d*fifa_data.defending_marking_awareness+
                  d*fifa_data.defending_standing_tackle+d*fifa_data.defending_sliding_tackle)/(2*a+9*b+4*c+5*d)

# %%
fifa_data_potLB=fifa_data[fifa_data.P0.isin(["LB", "LWB"])]

plt.figure(figsize=(15,6))
potLB= fifa_data_potLB.sort_values("LB",ascending= False)[:10]
x1= np.array(list(potLB["short_name"]))
y1= np.array(list(potLB["LB"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
# LCB and RCB, CB:

# %%
fifa_data.club_position.isin(["CB"]).value_counts()
# Out:
# False    19053
# True       186
# Name: club_position, dtype: int64

# %%
# sticking to only LCB and RCB:

# %%
#weak_foot,skill_moves,work_rate,body_type,real_face,release_clause_eur,player_tags,
#player_traits,pace,shooting,passing,dribbling,defending,physic,attacking_crossing,attacking_finishing,attacking_heading_accuracy,
#attacking_short_passing,attacking_volleys,skill_dribbling,skill_curve,skill_fk_accuracy,skill_long_passing,skill_ball_control,
#movement_acceleration,movement_sprint_speed,movement_agility,movement_reactions,movement_balance,power_shot_power,power_jumping,
#power_stamina,power_strength,power_long_shots,
#mentality_aggression,mentality_interceptions,mentality_positioning,mentality_vision,mentality_penalties,mentality_composure,
#defending_marking_awareness,defending_standing_tackle,defending_sliding_tackle

# %%
a=0.5
b=1
c=2
d=3

fifa_data["LCB"]= (a*fifa_data.weak_foot*20+a*fifa_data.shooting+
                  b*fifa_data.dribbling+b*fifa_data.movement_acceleration+
                  b*fifa_data.movement_sprint_speed+b*fifa_data.power_stamina+
                  c*fifa_data.movement_balance+c*fifa_data.mentality_aggression+c*fifa_data.mentality_vision+
                  c*fifa_data.movement_agility+c*fifa_data.movement_reactions+
                  c*fifa_data.pace+c*fifa_data.passing+c*fifa_data.mentality_composure+
                  d*fifa_data.mentality_interceptions+
                  d*fifa_data.defending+d*fifa_data.mentality_positioning+d*fifa_data.defending_marking_awareness+
                  d*fifa_data.power_jumping+d*fifa_data.physic+
                  d*fifa_data.defending_standing_tackle+d*fifa_data.defending_sliding_tackle)/(2*a+4*b+8*c+8*d)

# %%
fifa_data_potLCB=fifa_data[fifa_data.club_position.isin(["LCB"])]
#have to use club position, other has no LCB RCB

plt.figure(figsize=(15,6))
potLCB= fifa_data_potLCB.sort_values("LCB",ascending= False)[:10]
x1= np.array(list(potLCB["short_name"]))
y1= np.array(list(potLCB["LCB"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
a=0.5
b=1
c=2
d=3

fifa_data["RCB"]= (a*fifa_data.weak_foot*20+a*fifa_data.shooting+
                  b*fifa_data.dribbling+b*fifa_data.movement_acceleration+
                  b*fifa_data.movement_sprint_speed+b*fifa_data.power_stamina+
                  c*fifa_data.movement_balance+c*fifa_data.mentality_aggression+c*fifa_data.mentality_vision+
                  c*fifa_data.movement_agility+c*fifa_data.movement_reactions+
                  c*fifa_data.pace+c*fifa_data.passing+c*fifa_data.mentality_composure+
                  d*fifa_data.mentality_interceptions+
                  d*fifa_data.defending+d*fifa_data.mentality_positioning+d*fifa_data.defending_marking_awareness+
                  d*fifa_data.power_jumping+d*fifa_data.physic+
                  d*fifa_data.defending_standing_tackle+d*fifa_data.defending_sliding_tackle)/(2*a+4*b+8*c+8*d)

# %%
fifa_data_potRCB=fifa_data[fifa_data.club_position.isin(["RCB"])]
#have to use club position, other has no LCB RCB

plt.figure(figsize=(15,6))
potRCB= fifa_data_potRCB.sort_values("RCB",ascending= False)[:10]
x1= np.array(list(potRCB["short_name"]))
y1= np.array(list(potRCB["RCB"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
# Midfield:
# 2 CM, 1 OM, RW, LW

# %%
# CM: one more defensive (type 6), one more offensive (type 8):
#weak_foot,skill_moves,work_rate,body_type,real_face,release_clause_eur,player_tags,
#player_traits,pace,shooting,passing,dribbling,defending,physic,attacking_crossing,attacking_finishing,attacking_heading_accuracy,
#attacking_short_passing,attacking_volleys,skill_dribbling,skill_curve,skill_fk_accuracy,skill_long_passing,skill_ball_control,
#movement_acceleration,movement_sprint_speed,movement_agility,movement_reactions,movement_balance,power_shot_power,power_jumping,
#power_stamina,power_strength,power_long_shots,
#mentality_aggression,mentality_interceptions,mentality_positioning,mentality_vision,mentality_penalties,mentality_composure,
#defending_marking_awareness,defending_standing_tackle,defending_sliding_tackle

# %%
# CM6:
a=0.5
b=1
c=2
d=3 
fifa_data["CM6"]= (a*fifa_data.attacking_crossing+a*fifa_data.skill_dribbling+
                   b*fifa_data.shooting+b*fifa_data.dribbling+b*fifa_data.movement_acceleration+
                   b*fifa_data.movement_sprint_speed+b*fifa_data.movement_agility+b*fifa_data.movement_reactions+
                   b*fifa_data.movement_balance+b*fifa_data.power_jumping+b*fifa_data.power_strength+
                   b*fifa_data.power_long_shots+
                   c*fifa_data.weak_foot*20+c*fifa_data.pace+c*fifa_data.physic+c*fifa_data.attacking_short_passing+
                   c*fifa_data.skill_long_passing+c*fifa_data.power_stamina+c*fifa_data.mentality_interceptions+
                   c*fifa_data.mentality_vision+c*fifa_data.mentality_composure+c*fifa_data.defending_sliding_tackle+
                   d*fifa_data.work_rate+d*fifa_data.passing+d*fifa_data.defending+d*fifa_data.skill_ball_control+
                   d*fifa_data.mentality_aggression+d*fifa_data.mentality_positioning+d*fifa_data.defending_marking_awareness+
                   d*fifa_data.defending_standing_tackle)/(2*a+10*b+10*c+8*d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...

# %%
fifa_data.work_rate.unique()
# Out:
# array(['Medium/Low', 'High/Medium', 'High/Low', 'High/High',
#        'Medium/Medium', 'Medium/High', 'Low/High', 'Low/Medium',
#        'Low/Low'], dtype=object)

# %%
# CM6:
a=0.5
b=1
c=2
d=3 
fifa_data["CM6"]= (a*fifa_data.attacking_crossing+a*fifa_data.skill_dribbling+
                   b*fifa_data.shooting+b*fifa_data.dribbling+b*fifa_data.movement_acceleration+
                   b*fifa_data.movement_sprint_speed+b*fifa_data.movement_agility+b*fifa_data.movement_reactions+
                   b*fifa_data.movement_balance+b*fifa_data.power_jumping+b*fifa_data.power_strength+
                   b*fifa_data.power_long_shots+
                   c*fifa_data.weak_foot*20+c*fifa_data.pace+c*fifa_data.physic+c*fifa_data.attacking_short_passing+
                   c*fifa_data.skill_long_passing+c*fifa_data.power_stamina+c*fifa_data.mentality_interceptions+
                   c*fifa_data.mentality_vision+c*fifa_data.mentality_composure+c*fifa_data.defending_sliding_tackle+
                   d*fifa_data.passing+d*fifa_data.defending+d*fifa_data.skill_ball_control+
                   d*fifa_data.mentality_aggression+d*fifa_data.mentality_positioning+d*fifa_data.defending_marking_awareness+
                   d*fifa_data.defending_standing_tackle)/(2*a+10*b+10*c+8*d)

# %%
# RDM; CDM, LDM, all seem to be in P0 as CDM:

# %%
fifa_data.P0.isin(["CDM"]).value_counts()
# Out:
# False    17574
# True      1665
# Name: P0, dtype: int64

# %%
fifa_data_potCM6=fifa_data[fifa_data.P0.isin(["CDM"])]

plt.figure(figsize=(15,6))
potCM6= fifa_data_potCM6.sort_values("CM6",ascending= False)[:10]
x1= np.array(list(potCM6["short_name"]))
y1= np.array(list(potCM6["CM6"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
# offensive part: CM8

# %%
# CM8:
a=0.5
b=1
c=2
d=3 
fifa_data["CM8"]= (b*fifa_data.attacking_crossing+b*fifa_data.skill_dribbling+
                    b*fifa_data.movement_acceleration+b*fifa_data.defending_sliding_tackle+
                   b*fifa_data.movement_sprint_speed+b*fifa_data.movement_reactions+
                   b*fifa_data.movement_balance+b*fifa_data.power_jumping+b*fifa_data.power_strength+                   
                   c*fifa_data.shooting+c*fifa_data.dribbling+c*fifa_data.movement_agility+
                   c*fifa_data.power_long_shots+c*fifa_data.defending+c*fifa_data.defending_marking_awareness+
                   c*fifa_data.weak_foot*20+c*fifa_data.pace+c*fifa_data.physic+c*fifa_data.attacking_short_passing+
                   c*fifa_data.skill_long_passing+c*fifa_data.power_stamina+c*fifa_data.mentality_interceptions+
                   c*fifa_data.mentality_vision+c*fifa_data.mentality_composure+
                   d*fifa_data.passing+d*fifa_data.skill_ball_control+
                   d*fifa_data.mentality_aggression+d*fifa_data.mentality_positioning+
                   d*fifa_data.defending_standing_tackle)/(9*b+15*c+5*d)

# %%
fifa_data.P0.isin(["CM"]).value_counts()
# Out:
# False    17066
# True      2173
# Name: P0, dtype: int64

# %%
fifa_data_potCM8=fifa_data[fifa_data.P0.isin(["CM"])]

plt.figure(figsize=(15,6))
potCM8= fifa_data_potCM8.sort_values("CM8",ascending= False)[:10]
x1= np.array(list(potCM8["short_name"]))
y1= np.array(list(potCM8["CM8"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
# E. Can in Top 10?

# %%
# CM8:
a=0.5
b=1
c=2
d=3
e=10
fifa_data["CM8"]= (b*fifa_data.attacking_crossing+b*fifa_data.skill_dribbling+
                    b*fifa_data.movement_acceleration+b*fifa_data.defending_sliding_tackle+
                   b*fifa_data.movement_sprint_speed+b*fifa_data.movement_reactions+
                   b*fifa_data.movement_balance+b*fifa_data.power_jumping+b*fifa_data.power_strength+                   
                   c*fifa_data.shooting+c*fifa_data.dribbling+c*fifa_data.movement_agility+
                   c*fifa_data.power_long_shots+c*fifa_data.defending+c*fifa_data.defending_marking_awareness+
                   c*fifa_data.weak_foot*20+c*fifa_data.pace+c*fifa_data.physic+c*fifa_data.attacking_short_passing+
                   c*fifa_data.skill_long_passing+c*fifa_data.power_stamina+c*fifa_data.mentality_interceptions+
                   c*fifa_data.mentality_vision+c*fifa_data.mentality_composure+
                   d*fifa_data.mentality_aggression+d*fifa_data.mentality_positioning+
                   d*fifa_data.defending_standing_tackle+
                  e*fifa_data.passing+e*fifa_data.skill_ball_control)/(9*b+15*c+3*d+2*e)

# %%
fifa_data_potCM8=fifa_data[fifa_data.P0.isin(["CM"])]

plt.figure(figsize=(15,6))
potCM8= fifa_data_potCM8.sort_values("CM8",ascending= False)[:10]
x1= np.array(list(potCM8["short_name"]))
y1= np.array(list(potCM8["CM8"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
#  lets say he needs to be a tactician:

# %%
fifa_data.player_tags.unique()
# Out:
# array(['#Dribbler, #Distance Shooter, #FK Specialist, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Aerial Threat, #Distance Shooter, #Clinical Finisher, #Complete Forward',
#        '#Aerial Threat, #Dribbler, #Distance Shooter, #Crosser, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Speedster, #Dribbler, #Playmaker, #FK Specialist, #Acrobat, #Complete Midfielder',
#        '#Dribbler, #Playmaker, #Engine, #Distance Shooter, #Crosser, #Complete Midfielder',
#        nan,
#        '#Speedster, #Dribbler, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Distance Shooter, #Clinical Finisher',
#        '#Tackling, #Tactician\xa0', '#Poacher',
#        '#Dribbler, #Engine, #Distance Shooter, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Engine, #Tackling, #Tactician, #Strength, #Complete Defender',
#        '#Tackling, #Tactician, #Strength, #Complete Defender', '#Crosser',
# ...

# %%
fifa_data.player_tags.str.split(",",expand=True)
# Out:
#                     0                   1                    2  \
# 0           #Dribbler   #Distance Shooter       #FK Specialist
# 1      #Aerial Threat   #Distance Shooter   #Clinical Finisher
# 2      #Aerial Threat           #Dribbler    #Distance Shooter
# 3          #Speedster           #Dribbler           #Playmaker
# 4           #Dribbler          #Playmaker              #Engine
# ...               ...                 ...                  ...
# 19234             NaN                 NaN                  NaN
# 19235             NaN                 NaN                  NaN
# 19236             NaN                 NaN                  NaN
# 19237             NaN                 NaN                  NaN
# 19238             NaN                 NaN                  NaN
#
#                         3                    4                      5  \
# 0                #Acrobat   #Clinical Finisher      #Complete Forward
# ...

# %%
fifa_data["PT0"]=fifa_data.player_tags.str.split(",",expand=True)[0]
fifa_data["PT1"]=fifa_data.player_tags.str.split(",",expand=True)[1]
fifa_data["PT2"]=fifa_data.player_tags.str.split(",",expand=True)[2]
fifa_data["PT3"]=fifa_data.player_tags.str.split(",",expand=True)[3]
fifa_data["PT4"]=fifa_data.player_tags.str.split(",",expand=True)[4]
fifa_data["PT5"]=fifa_data.player_tags.str.split(",",expand=True)[5]
fifa_data["PT6"]=fifa_data.player_tags.str.split(",",expand=True)[6]
#get rid of whitespaces:
fifa_data.PT0.str.strip()
fifa_data.PT1.str.strip()
fifa_data.PT2.str.strip()
fifa_data.PT3.str.strip()
fifa_data.PT4.str.strip()
fifa_data.PT5.str.strip()
fifa_data.PT6.str.strip()
# Out:
# 0                     None
# 1                     None
# 2        #Complete Forward
# 3                     None
# 4                     None
#                ...
# 19234                  NaN
# 19235                  NaN
# 19236                  NaN
# 19237                  NaN
# 19238                  NaN
# Name: PT6, Length: 19239, dtype: object

# %%
m0=fifa_data.PT0.str.contains("#Tactician")
m1=fifa_data.PT1.str.contains("#Tactician")
m2=fifa_data.PT2.str.contains("#Tactician")
m3=fifa_data.PT3.str.contains("#Tactician")
m4=fifa_data.PT4.str.contains("#Tactician")
m5=fifa_data.PT5.str.contains("#Tactician")
Tactician = fifa_data[(m0 | m1 | m2| m3| m4| m5| m6)]

# %%
plt.figure(figsize=(15,6))
potCM8= Tactician.sort_values("CM8",ascending= False)[:10]
x1= np.array(list(potCM8["short_name"]))
y1= np.array(list(potCM8["CM8"]))

sns.barplot(x=x1,y=y1,palette="colorblind")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
# KdB no tactician?

# %%
fifa_data.loc[fifa_data.long_name == "Kevin De Bruyne"]
# Out:
#      short_name        long_name player_positions  overall  potential  \
# 4  K. De Bruyne  Kevin De Bruyne          CM, CAM       91         91
#
#      value_eur  wage_eur  age         dob  height_cm  ...        RCB  \
# 4  125500000.0  350000.0   30  1991-06-28        181  ...  75.755556
#
#          CM6        CM8        PT0          PT1       PT2                 PT3  \
# 4  76.218182  82.259259  #Dribbler   #Playmaker   #Engine   #Distance Shooter
#
#          PT4                    PT5   PT6
# 4   #Crosser   #Complete Midfielder  None
#
# [1 rows x 126 columns]

# %%
# Heart: OM, lets look closer at other attributes:
#FK Specialist, #Playmaker, #Distance Shooter
fifa_data.player_tags.unique()
# Out:
# array(['#Dribbler, #Distance Shooter, #FK Specialist, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Aerial Threat, #Distance Shooter, #Clinical Finisher, #Complete Forward',
#        '#Aerial Threat, #Dribbler, #Distance Shooter, #Crosser, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Speedster, #Dribbler, #Playmaker, #FK Specialist, #Acrobat, #Complete Midfielder',
#        '#Dribbler, #Playmaker, #Engine, #Distance Shooter, #Crosser, #Complete Midfielder',
#        nan,
#        '#Speedster, #Dribbler, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Distance Shooter, #Clinical Finisher',
#        '#Tackling, #Tactician\xa0', '#Poacher',
#        '#Dribbler, #Engine, #Distance Shooter, #Acrobat, #Clinical Finisher, #Complete Forward',
#        '#Engine, #Tackling, #Tactician, #Strength, #Complete Defender',
#        '#Tackling, #Tactician, #Strength, #Complete Defender', '#Crosser',
# ...

# %%
 #FK Specialist, #Distance Shooter,#Playmaker
fifa_data.player_tags.str.contains("Dribbler").value_counts()
# Out:
# False    1349
# True       92
# Name: player_tags, dtype: int64

# %%
m0=fifa_data.PT0.str.contains("#FK Specialist")
m1=fifa_data.PT1.str.contains("#FK Specialist")
m2=fifa_data.PT2.str.contains("#FK Specialist")
m3=fifa_data.PT3.str.contains("#FK Specialist")
m4=fifa_data.PT4.str.contains("#FK Specialist")
m5=fifa_data.PT5.str.contains("#FK Specialist")
m6=fifa_data.PT6.str.contains("#FK Specialist")

m7=fifa_data.PT0.str.contains("#Playmaker")
m8=fifa_data.PT1.str.contains("#Playmaker")
m9=fifa_data.PT2.str.contains("#Playmaker")
m10=fifa_data.PT3.str.contains("#Playmaker")
m11=fifa_data.PT4.str.contains("#Playmaker")
m12=fifa_data.PT5.str.contains("#Playmaker")
m13=fifa_data.PT6.str.contains("#Playmaker")

m14=fifa_data.PT0.str.contains("#Distance Shooter")
m15=fifa_data.PT1.str.contains("#Distance Shooter")
m16=fifa_data.PT2.str.contains("#Distance Shooter")
m17=fifa_data.PT3.str.contains("#Distance Shooter")
m18=fifa_data.PT4.str.contains("#Distance Shooter")
m19=fifa_data.PT5.str.contains("#Distance Shooter")
m20=fifa_data.PT6.str.contains("#Distance Shooter")

fifa_data[(m0 | m1 | m2| m3| m4| m5|m6 ) & ( m7 | m8| m9| m10| m11|m12|m13) & (m14| m15| m16| m17|m18|m19|m20)]
# Out:
#          short_name                      long_name player_positions  overall  \
# 28  Bruno Fernandes  Bruno Miguel Borges Fernandes              CAM       88
#
#     potential    value_eur  wage_eur  age         dob  height_cm  ...  \
# 28         89  107500000.0  250000.0   26  1994-09-08        179  ...
#
#           RCB        CM6        CM8         PT0       PT1                 PT2  \
# 28  77.444444  75.181818  80.592593  #Playmaker   #Engine   #Distance Shooter
#
#           PT3              PT4                    PT5   PT6
# 28   #Crosser   #FK Specialist   #Complete Midfielder  None
#
# [1 rows x 126 columns]
